# %% [markdown]
# # Predicting Boston Housing Prices
#
# ## Updating a model using SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this notebook, we will continue working with the [Boston Housing Dataset](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html). Our goal in this notebook will be to train two different models and to use SageMaker to switch a deployed endpoint from using one model to the other. One of the benefits of using SageMaker to do this is that we can make the change without interrupting service. What this means is that we can continue sending data to the endpoint and at no point will that endpoint disappear.
#
# ## General Outline
#
# Typically, when using a notebook instance with SageMaker, you will proceed through the following steps. Of course, not every step will need to be done with each project. Also, there is quite a lot of room for variation in many of the steps, as you will see throughout these lessons.
#
# 1. Download or otherwise retrieve the data.
# 2. Process / Prepare the data.
# 3. Upload the processed data to S3.
# 4. Train a chosen model.
# 5. Test the trained model (typically using a batch transform job).
# 6. Deploy the trained model.
# 7. Use the deployed model.
#
# In this notebook we will be skipping step 5, testing the model. In addition, we will perform steps 4, 6 and 7 multiple times with different models.

# %% [markdown]
# ## Step 0: Setting up the notebook
#
# We begin by setting up all of the necessary bits required to run our notebook. To start that means loading all of the Python modules we will need.

# %%
# %matplotlib inline

import os

import numpy as np
import pandas as pd

from pprint import pprint
import matplotlib.pyplot as plt
from time import gmtime, strftime

from sklearn.datasets import load_boston
import sklearn.model_selection

# %% [markdown]
# In addition to the modules above, we need to import the various bits of SageMaker that we will be using.

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.predictor import csv_serializer

# This is an object that represents the SageMaker session that we are currently operating in. This
# object contains some useful information that we will need to access later such as our region.
session = sagemaker.Session()

# This is an object that represents the IAM role that we are currently assigned. When we construct
# and launch the training job later we will need to tell it what IAM role it should have. Since our
# use case is relatively simple we will simply assign the training job the role we currently have.
role = get_execution_role()

# %% [markdown]
# ## Step 1: Downloading the data
#
# Fortunately, this dataset can be retrieved using sklearn and so this step is relatively straightforward.

# %%
boston = load_boston()

# %% [markdown]
# ## Step 2: Preparing and splitting the data
#
# Given that this is clean tabular data, we don't need to do any processing. However, we do need to split the rows in the dataset up into train, test and validation sets.

# %%
# First we package up the input data and the target variable (the median value) as pandas dataframes. This
# will make saving the data to a file a little easier later on.

X_bos_pd = pd.DataFrame(boston.data, columns=boston.feature_names)
Y_bos_pd = pd.DataFrame(boston.target)

# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X_bos_pd, Y_bos_pd, test_size=0.33)

# Then we split the training set further into 2/3 training and 1/3 validation sets.
X_train, X_val, Y_train, Y_val = sklearn.model_selection.train_test_split(X_train, Y_train, test_size=0.33)

# %% [markdown]
# ## Step 3: Uploading the training and validation files to S3
#
# When a training job is constructed using SageMaker, a container is executed which performs the training operation. This container is given access to data that is stored in S3. This means that we need to upload the data we want to use for training to S3. We can use the SageMaker API to do this and hide some of the details.
#
# ### Save the data locally
#
# First we need to create the train and validation csv files which we will then upload to S3.

# %%
# This is our local data directory. We need to make sure that it exists.
data_dir = '../data/boston'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# We use pandas to save our train and validation data to csv files. Note that we make sure not to include header
# information or an index as this is required by the built in algorithms provided by Amazon. Also, it is assumed
# that the first entry in each row is the target variable.

pd.concat([Y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([Y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %% [markdown]
# ### Upload to S3
#
# Since we are currently running inside of a SageMaker session, we can use the object which represents this session to upload our data to the 'default' S3 bucket. Note that it is good practice to provide a custom prefix (essentially an S3 folder) to make sure that you don't accidentally interfere with data uploaded from some other notebook or project.

# %%
prefix = 'boston-update-endpoints'

val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ## Step 4 (A): Train the XGBoost model
#
# Now that we have the training and validation data uploaded to S3, we can construct our XGBoost model and train it. We will be making use of the high level SageMaker API to do this which will make the resulting code a little easier to read at the cost of some flexibility.
#
# To construct an estimator, the object which we wish to train, we need to provide the location of a container which contains the training code. Since we are using a built in algorithm this container is provided by Amazon. However, the full name of the container is a bit lengthy and depends on the region that we are operating in. Fortunately, SageMaker provides a useful utility method called `get_image_uri` that constructs the image name for us.
#
# To use the `get_image_uri` method we need to provide it with our current region, which can be obtained from the session object, and the name of the algorithm we wish to use. In this notebook we will be using XGBoost however you could try another algorithm if you wish. The list of built in algorithms can be found in the list of [Common Parameters](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html).

# %%
# As stated above, we use this utility method to construct the image name for the training container.
xgb_container = get_image_uri(session.boto_region_name, 'xgboost')

# Now that we know which container to use, we can construct the estimator object.
xgb = sagemaker.estimator.Estimator(xgb_container, # The name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %% [markdown]
# Before asking SageMaker to begin the training job, we should probably set any model specific hyperparameters. There are quite a few that can be set when using the XGBoost algorithm, below are just a few of them. If you would like to change the hyperparameters below or modify additional ones you can find additional information on the [XGBoost hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html)

# %%
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)

# %% [markdown]
# Now that we have our estimator object completely set up, it is time to train it. To do this we make sure that SageMaker knows our input data is in csv format and then execute the `fit` method.

# %%
# This is a wrapper around the location of our train and validation data, to make sure that SageMaker
# knows our data is in csv format.
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='text/csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2019-12-16 05:10:59 Starting - Starting the training job...
# 2019-12-16 05:11:00 Starting - Launching requested ML instances......
# 2019-12-16 05:12:14 Starting - Preparing the instances for training......
# 2019-12-16 05:13:16 Downloading - Downloading input data...
# 2019-12-16 05:13:49 Training - Downloading the training image..Arguments: train
# [2019-12-16:05:14:09:INFO] Running standalone xgboost training.
# [2019-12-16:05:14:09:INFO] File size need to be processed in the node: 0.03mb. Available memory size in the node: 8520.71mb
# [2019-12-16:05:14:09:INFO] Determined delimiter of CSV input is ','
# [05:14:09] S3DistributionType set as FullyReplicated
# [05:14:09] 227x13 matrix with 2951 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2019-12-16:05:14:09:INFO] Determined delimiter of CSV input is ','
# [05:14:09] S3DistributionType set as FullyReplicated
# [05:14:09] 112x13 matrix with 1456 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:19.6812#011validation-rmse:18.7192
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [1]#011train-rmse:16.0007#011validation-rmse:15.1947
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [2]#011train-rmse:13.0878#011validation-rmse:12.4193
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [3]#011train-rmse:10.7199#011validation-rmse:10.1559
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [4]#011train-rmse:8.89256#011validation-rmse:8.38389
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [5]#011train-rmse:7.43262#011validation-rmse:7.03117
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-rmse:6.24275#011validation-rmse:6.01515
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-rmse:5.31403#011validation-rmse:5.12016
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-rmse:4.56052#011validation-rmse:4.52729
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [9]#011train-rmse:3.97736#011validation-rmse:4.06665
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:3.49149#011validation-rmse:3.74597
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [11]#011train-rmse:3.10054#011validation-rmse:3.47078
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:2.83176#011validation-rmse:3.27311
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:2.58672#011validation-rmse:3.10823
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:2.42854#011validation-rmse:3.03815
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [15]#011train-rmse:2.28789#011validation-rmse:2.95653
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [16]#011train-rmse:2.15745#011validation-rmse:2.94185
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [17]#011train-rmse:2.04213#011validation-rmse:2.96247
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [18]#011train-rmse:1.95452#011validation-rmse:2.9469
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [19]#011train-rmse:1.85998#011validation-rmse:2.96357
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [20]#011train-rmse:1.76792#011validation-rmse:2.92766
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [21]#011train-rmse:1.69793#011validation-rmse:2.9596
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [22]#011train-rmse:1.66574#011validation-rmse:2.95894
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [23]#011train-rmse:1.63412#011validation-rmse:2.95516
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [24]#011train-rmse:1.57246#011validation-rmse:2.95766
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [25]#011train-rmse:1.52707#011validation-rmse:2.97016
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [26]#011train-rmse:1.47858#011validation-rmse:2.96389
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [27]#011train-rmse:1.43989#011validation-rmse:2.99371
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [28]#011train-rmse:1.40713#011validation-rmse:3.00294
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [29]#011train-rmse:1.3627#011validation-rmse:3.01945
# [05:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [30]#011train-rmse:1.32005#011validation-rmse:3.01628
# Stopping. Best iteration:
# [20]#011train-rmse:1.76792#011validation-rmse:2.92766
#
#
# 2019-12-16 05:14:21 Uploading - Uploading generated training model
# 2019-12-16 05:14:21 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 65

# %% [markdown]
# ## Step 5: Test the trained model
#
# We will be skipping this step for now.
#
#
# ## Step 6 (A): Deploy the trained model
#
# Even though we used the high level approach to construct and train the XGBoost model, we will be using the lower level approach to deploy it. One of the reasons for this is so that we have additional control over how the endpoint is constructed. This will be a little more clear later on when construct more advanced endpoints.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
# Remember that a model needs to have a unique name
xgb_model_name = "boston-update-xgboost-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the xgboost container that we used for training
# can also be used for inference and the model artifacts come from the previous call to fit.
xgb_primary_container = {
    "Image": xgb_container,
    "ModelDataUrl": xgb.model_data
}

# And lastly we construct the SageMaker model
xgb_model_info = session.sagemaker_client.create_model(
                                ModelName = xgb_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = xgb_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have a model we can start putting together the endpoint. Recall that to do this we need to first create an endpoint configuration, essentially the blueprint that SageMaker will use to build the endpoint itself.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
xgb_endpoint_config_name = "boston-update-xgboost-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
xgb_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = xgb_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": xgb_model_name,
                                "VariantName": "XGB-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = xgb_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# ---------------------------------------------------------------------------------------------------------------!

# %% [markdown]
# ## Step 7 (A): Use the model
#
# Now that our model is trained and deployed we can send some test data to it and evaluate the results.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7fca62ff4470>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 05:31:13 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'd4f84a38-6dcb-46bf-adc9-03791b42ee40'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'd4f84a38-6dcb-46bf-adc9-03791b42ee40',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '40.9679641724'

# %%
Y_test.values[0]
# Out:
# array([43.1])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the XGBoost endpoint works, we can shut it down. We will make use of it again later.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '1b8a3071-7d8d-42cd-8fba-c1a79897bb20',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '1b8a3071-7d8d-42cd-8fba-c1a79897bb20',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Mon, 16 Dec 2019 05:31:21 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 4 (B): Train the Linear model
#
# Suppose we are working in an environment where the XGBoost model that we trained earlier is becoming too costly. Perhaps the number of calls to our endpoint has increased and the length of time it takes to perform inference with the XGBoost model is becoming problematic.
#
# A possible solution might be to train a simpler model to see if it performs nearly as well. In our case, we will construct a linear model. The process of doing this is the same as for creating the XGBoost model that we created earlier, although there are different hyperparameters that we need to set.

# %%
# Similar to the XGBoost model, we will use the utility method to construct the image name for the training container.
linear_container = get_image_uri(session.boto_region_name, 'linear-learner')

# Now that we know which container to use, we can construct the estimator object.
linear = sagemaker.estimator.Estimator(linear_container, # The name of the training container
                                        role,      # The IAM role to use (our current role in this case)
                                        train_instance_count=1, # The number of instances to use for training
                                        train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                        output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                            # Where to save the output (the model artifacts)
                                        sagemaker_session=session) # The current SageMaker session

# %% [markdown]
# Before asking SageMaker to train our model, we need to set some hyperparameters. In this case we will be using a linear model so the number of hyperparameters we need to set is much fewer. For more details see the [Linear model hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html)

# %%
linear.set_hyperparameters(feature_dim=13, # Our data has 13 feature columns
                           predictor_type='regressor', # We wish to create a regression model
                           mini_batch_size=200) # Here we set how many samples to look at in each iteration

# %% [markdown]
# Now that the hyperparameters have been set, we can ask SageMaker to fit the linear model to our data.

# %%
linear.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2019-12-16 05:31:34 Starting - Starting the training job...
# 2019-12-16 05:31:35 Starting - Launching requested ML instances......
# 2019-12-16 05:32:42 Starting - Preparing the instances for training......
# 2019-12-16 05:33:53 Downloading - Downloading input data...
# 2019-12-16 05:34:34 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# [12/16/2019 05:34:36 INFO 140618816755520] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/16/2019 05:34:36 INFO 140618816755520] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'13', u'mini_batch_size': u'200', u'predictor_type': u'regressor'}
# [12/16/2019 05:34:36 INFO 140618816755520] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'13', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/16/2019 05:34:36 WARNING 140618816755520] Loggers have already been setup.
# Process 1 is a worker.
# [12/16/2019 05:34:36 INFO 140618816755520] Using default worker.
# [12/16/2019 05:34:37 INFO 140618816755520] Create Store: local
# [12/16/2019 05:34:37 INFO 140618816755520] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fe40d062390>
# [12/16/2019 05:34:37 INFO 140618816755520] Scaling model computed with parameters:
#  {'stdev_weight':
# [9.4960327e+00 2.3418829e+01 6.9940972e+00 2.4652585e-01 1.2026914e-01
#  7.6133937e-01 2.7660646e+01 2.1649776e+00 8.5573130e+00 1.6554135e+02
#  2.2665269e+00 8.4598541e+01 7.1145158e+00]
# <NDArray 13 @cpu(0)>, 'stdev_label':
# [9.30789]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [22.811499]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.46186352e+00 1.08275003e+01 1.14283495e+01 6.49999976e-02
#  5.63848972e-01 6.28272533e+00 6.95830002e+01 3.68793488e+00
#  9.18000031e+00 4.03725006e+02 1.83174992e+01 3.59253754e+02
#  1.22972994e+01]
# <NDArray 13 @cpu(0)>}
# [12/16/2019 05:34:37 INFO 140618816755520] nvidia-smi took: 0.0251760482788 secs to identify 0 gpus
# [12/16/2019 05:34:37 INFO 140618816755520] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 427, "sum": 427.0, "min": 427}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1576474477.165079, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576474477.165038}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9657916259765625, "sum": 0.9657916259765625, "min": 0.9657916259765625}}, "EndTime": 1576474477.206291, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206236}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8876742553710938, "sum": 0.8876742553710938, "min": 0.8876742553710938}}, "EndTime": 1576474477.206363, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206349}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.335720977783203, "sum": 1.335720977783203, "min": 1.335720977783203}}, "EndTime": 1576474477.206427, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206413}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8958724212646484, "sum": 0.8958724212646484, "min": 0.8958724212646484}}, "EndTime": 1576474477.20648, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206465}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8779960632324219, "sum": 0.8779960632324219, "min": 0.8779960632324219}}, "EndTime": 1576474477.206544, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206526}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0069192504882813, "sum": 1.0069192504882813, "min": 1.0069192504882813}}, "EndTime": 1576474477.206609, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206597}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1418216705322266, "sum": 1.1418216705322266, "min": 1.1418216705322266}}, "EndTime": 1576474477.206668, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206657}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1100503540039062, "sum": 1.1100503540039062, "min": 1.1100503540039062}}, "EndTime": 1576474477.206707, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206698}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9417362213134766, "sum": 0.9417362213134766, "min": 0.9417362213134766}}, "EndTime": 1576474477.206744, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206735}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.412857208251953, "sum": 1.412857208251953, "min": 1.412857208251953}}, "EndTime": 1576474477.206775, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206767}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8825611114501953, "sum": 0.8825611114501953, "min": 0.8825611114501953}}, "EndTime": 1576474477.206821, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206807}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1374131774902343, "sum": 1.1374131774902343, "min": 1.1374131774902343}}, "EndTime": 1576474477.206868, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206858}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0197950744628905, "sum": 1.0197950744628905, "min": 1.0197950744628905}}, "EndTime": 1576474477.206906, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206897}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0360198974609376, "sum": 1.0360198974609376, "min": 1.0360198974609376}}, "EndTime": 1576474477.206954, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206938}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8994680786132813, "sum": 0.8994680786132813, "min": 0.8994680786132813}}, "EndTime": 1576474477.207015, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.206998}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0275587463378906, "sum": 1.0275587463378906, "min": 1.0275587463378906}}, "EndTime": 1576474477.207077, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207059}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.041739501953125, "sum": 1.041739501953125, "min": 1.041739501953125}}, "EndTime": 1576474477.207144, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207126}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.868109130859375, "sum": 0.868109130859375, "min": 0.868109130859375}}, "EndTime": 1576474477.207206, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207189}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2356263732910155, "sum": 1.2356263732910155, "min": 1.2356263732910155}}, "EndTime": 1576474477.207243, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207234}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0521512603759766, "sum": 1.0521512603759766, "min": 1.0521512603759766}}, "EndTime": 1576474477.207273, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207265}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7941594696044922, "sum": 0.7941594696044922, "min": 0.7941594696044922}}, "EndTime": 1576474477.20733, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207314}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1330781555175782, "sum": 1.1330781555175782, "min": 1.1330781555175782}}, "EndTime": 1576474477.20739, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207374}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.76640380859375, "sum": 0.76640380859375, "min": 0.76640380859375}}, "EndTime": 1576474477.207449, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207433}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8735805511474609, "sum": 0.8735805511474609, "min": 0.8735805511474609}}, "EndTime": 1576474477.207483, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207475}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9647636413574219, "sum": 0.9647636413574219, "min": 0.9647636413574219}}, "EndTime": 1576474477.20753, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207516}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.951324462890625, "sum": 0.951324462890625, "min": 0.951324462890625}}, "EndTime": 1576474477.207594, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207577}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2325653839111328, "sum": 1.2325653839111328, "min": 1.2325653839111328}}, "EndTime": 1576474477.207655, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207637}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1336902618408202, "sum": 1.1336902618408202, "min": 1.1336902618408202}}, "EndTime": 1576474477.207726, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207708}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0292792510986328, "sum": 1.0292792510986328, "min": 1.0292792510986328}}, "EndTime": 1576474477.207792, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207775}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9461780548095703, "sum": 0.9461780548095703, "min": 0.9461780548095703}}, "EndTime": 1576474477.207853, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207836}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1276847076416017, "sum": 1.1276847076416017, "min": 1.1276847076416017}}, "EndTime": 1576474477.207922, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207903}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1458235931396485, "sum": 1.1458235931396485, "min": 1.1458235931396485}}, "EndTime": 1576474477.207995, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.207977}
#
# [12/16/2019 05:34:37 INFO 140618816755520] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.965791625977
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.499215262276785, "sum": 63.499215262276785, "min": 63.499215262276785}}, "EndTime": 1576474477.253225, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253172}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.519927978515625, "sum": 56.519927978515625, "min": 56.519927978515625}}, "EndTime": 1576474477.25329, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253276}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 90.67081124441964, "sum": 90.67081124441964, "min": 90.67081124441964}}, "EndTime": 1576474477.253357, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253339}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 55.786023821149556, "sum": 55.786023821149556, "min": 55.786023821149556}}, "EndTime": 1576474477.253436, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253416}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.66502162388393, "sum": 63.66502162388393, "min": 63.66502162388393}}, "EndTime": 1576474477.253507, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253489}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 46.27049037388393, "sum": 46.27049037388393, "min": 46.27049037388393}}, "EndTime": 1576474477.253573, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253555}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 51.66789027622768, "sum": 51.66789027622768, "min": 51.66789027622768}}, "EndTime": 1576474477.253658, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.25364}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.185289655412944, "sum": 54.185289655412944, "min": 54.185289655412944}}, "EndTime": 1576474477.25372, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253703}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 55.97991943359375, "sum": 55.97991943359375, "min": 55.97991943359375}}, "EndTime": 1576474477.253783, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253766}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 94.95792061941964, "sum": 94.95792061941964, "min": 94.95792061941964}}, "EndTime": 1576474477.253845, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253828}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.917227608816965, "sum": 53.917227608816965, "min": 53.917227608816965}}, "EndTime": 1576474477.253909, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253891}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 74.00150844029018, "sum": 74.00150844029018, "min": 74.00150844029018}}, "EndTime": 1576474477.253983, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.253964}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.19517299107143, "sum": 54.19517299107143, "min": 54.19517299107143}}, "EndTime": 1576474477.25405, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254032}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.200326102120535, "sum": 56.200326102120535, "min": 56.200326102120535}}, "EndTime": 1576474477.254115, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254097}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.17868913922992, "sum": 70.17868913922992, "min": 70.17868913922992}}, "EndTime": 1576474477.254183, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254165}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.77656773158482, "sum": 50.77656773158482, "min": 50.77656773158482}}, "EndTime": 1576474477.254249, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254231}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.80934797014508, "sum": 68.80934797014508, "min": 68.80934797014508}}, "EndTime": 1576474477.254314, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254295}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 52.220894949776785, "sum": 52.220894949776785, "min": 52.220894949776785}}, "EndTime": 1576474477.254379, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254361}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 81.47089494977679, "sum": 81.47089494977679, "min": 81.47089494977679}}, "EndTime": 1576474477.254445, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254427}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.9415762765067, "sum": 65.9415762765067, "min": 65.9415762765067}}, "EndTime": 1576474477.254516, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254498}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 55.120274135044646, "sum": 55.120274135044646, "min": 55.120274135044646}}, "EndTime": 1576474477.25458, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254562}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.600760323660715, "sum": 47.600760323660715, "min": 47.600760323660715}}, "EndTime": 1576474477.254643, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254626}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 60.091544015066965, "sum": 60.091544015066965, "min": 60.091544015066965}}, "EndTime": 1576474477.254706, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.25469}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 62.04188755580357, "sum": 62.04188755580357, "min": 62.04188755580357}}, "EndTime": 1576474477.25477, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254753}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.70269775390625, "sum": 66.70269775390625, "min": 66.70269775390625}}, "EndTime": 1576474477.254832, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254815}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 62.72687203543527, "sum": 62.72687203543527, "min": 62.72687203543527}}, "EndTime": 1576474477.254894, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.254878}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 87.18675885881696, "sum": 87.18675885881696, "min": 87.18675885881696}}, "EndTime": 1576474477.254956, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.25494}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 78.16499546595982, "sum": 78.16499546595982, "min": 78.16499546595982}}, "EndTime": 1576474477.255031, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.255012}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 86.07462855747768, "sum": 86.07462855747768, "min": 86.07462855747768}}, "EndTime": 1576474477.255095, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.255077}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 100.13698032924107, "sum": 100.13698032924107, "min": 100.13698032924107}}, "EndTime": 1576474477.255159, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.255142}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.8134024483817, "sum": 71.8134024483817, "min": 71.8134024483817}}, "EndTime": 1576474477.255223, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.255207}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.43399919782367, "sum": 65.43399919782367, "min": 65.43399919782367}}, "EndTime": 1576474477.255287, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.255271}
#
# [12/16/2019 05:34:37 INFO 140618816755520] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=63.4992152623
# [12/16/2019 05:34:37 INFO 140618816755520] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=46.2704903739
# [12/16/2019 05:34:37 INFO 140618816755520] Epoch 0: Loss improved. Updating best model
# [12/16/2019 05:34:37 INFO 140618816755520] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Total Batches Seen": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Total Records Seen": {"count": 1, "max": 654, "sum": 654.0, "min": 654}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1576474477.257032, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576474477.165276}
#
# [12/16/2019 05:34:37 INFO 140618816755520] #throughput_metric: host=algo-1, train throughput=2470.85525063 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9137709045410156, "sum": 0.9137709045410156, "min": 0.9137709045410156}}, "EndTime": 1576474477.283849, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.283799}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8429843139648437, "sum": 0.8429843139648437, "min": 0.8429843139648437}}, "EndTime": 1576474477.283923, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.283904}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.264788360595703, "sum": 1.264788360595703, "min": 1.264788360595703}}, "EndTime": 1576474477.283994, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.283975}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8503328704833985, "sum": 0.8503328704833985, "min": 0.8503328704833985}}, "EndTime": 1576474477.284067, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284049}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7790039825439453, "sum": 0.7790039825439453, "min": 0.7790039825439453}}, "EndTime": 1576474477.284141, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284123}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5827636337280273, "sum": 0.5827636337280273, "min": 0.5827636337280273}}, "EndTime": 1576474477.284207, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284188}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6770011138916016, "sum": 0.6770011138916016, "min": 0.6770011138916016}}, "EndTime": 1576474477.28427, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284253}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6896247863769531, "sum": 0.6896247863769531, "min": 0.6896247863769531}}, "EndTime": 1576474477.284351, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284334}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8962628173828125, "sum": 0.8962628173828125, "min": 0.8962628173828125}}, "EndTime": 1576474477.284424, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284406}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3380908203125, "sum": 1.3380908203125, "min": 1.3380908203125}}, "EndTime": 1576474477.284486, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284469}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8405204010009766, "sum": 0.8405204010009766, "min": 0.8405204010009766}}, "EndTime": 1576474477.28454, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284525}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0807174682617187, "sum": 1.0807174682617187, "min": 1.0807174682617187}}, "EndTime": 1576474477.284603, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284585}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7136090087890625, "sum": 0.7136090087890625, "min": 0.7136090087890625}}, "EndTime": 1576474477.284674, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284656}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7115019226074218, "sum": 0.7115019226074218, "min": 0.7115019226074218}}, "EndTime": 1576474477.284741, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284724}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8519718933105469, "sum": 0.8519718933105469, "min": 0.8519718933105469}}, "EndTime": 1576474477.284802, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284785}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6486544036865234, "sum": 0.6486544036865234, "min": 0.6486544036865234}}, "EndTime": 1576474477.284866, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284849}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9856465148925782, "sum": 0.9856465148925782, "min": 0.9856465148925782}}, "EndTime": 1576474477.284929, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.28491}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8287638854980469, "sum": 0.8287638854980469, "min": 0.8287638854980469}}, "EndTime": 1576474477.284992, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.284975}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.175190200805664, "sum": 1.175190200805664, "min": 1.175190200805664}}, "EndTime": 1576474477.285054, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285037}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9990334320068359, "sum": 0.9990334320068359, "min": 0.9990334320068359}}, "EndTime": 1576474477.285123, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285106}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6815474700927734, "sum": 0.6815474700927734, "min": 0.6815474700927734}}, "EndTime": 1576474477.285184, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285168}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6138187408447265, "sum": 0.6138187408447265, "min": 0.6138187408447265}}, "EndTime": 1576474477.285245, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285228}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.731106948852539, "sum": 0.731106948852539, "min": 0.731106948852539}}, "EndTime": 1576474477.285308, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285291}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7558822631835938, "sum": 0.7558822631835938, "min": 0.7558822631835938}}, "EndTime": 1576474477.285369, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285353}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9706895446777344, "sum": 0.9706895446777344, "min": 0.9706895446777344}}, "EndTime": 1576474477.285434, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285417}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9612078094482421, "sum": 0.9612078094482421, "min": 0.9612078094482421}}, "EndTime": 1576474477.285496, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285479}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1901380157470702, "sum": 1.1901380157470702, "min": 1.1901380157470702}}, "EndTime": 1576474477.285558, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285542}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.110153579711914, "sum": 1.110153579711914, "min": 1.110153579711914}}, "EndTime": 1576474477.285645, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285603}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0559710693359374, "sum": 1.0559710693359374, "min": 1.0559710693359374}}, "EndTime": 1576474477.285707, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.28569}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3031240844726562, "sum": 1.3031240844726562, "min": 1.3031240844726562}}, "EndTime": 1576474477.28577, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285753}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9103614807128906, "sum": 0.9103614807128906, "min": 0.9103614807128906}}, "EndTime": 1576474477.285831, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285814}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9375154113769532, "sum": 0.9375154113769532, "min": 0.9375154113769532}}, "EndTime": 1576474477.285894, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.285877}
#
# [12/16/2019 05:34:37 INFO 140618816755520] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.913770904541
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 58.69800240652902, "sum": 58.69800240652902, "min": 58.69800240652902}}, "EndTime": 1576474477.333755, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.3337}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 52.160330636160715, "sum": 52.160330636160715, "min": 52.160330636160715}}, "EndTime": 1576474477.333831, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.33381}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.40572684151786, "sum": 84.40572684151786, "min": 84.40572684151786}}, "EndTime": 1576474477.333905, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.333884}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 51.518445696149556, "sum": 51.518445696149556, "min": 51.518445696149556}}, "EndTime": 1576474477.333971, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.333953}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 48.59108189174107, "sum": 48.59108189174107, "min": 48.59108189174107}}, "EndTime": 1576474477.334036, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334018}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 55.350856236049104, "sum": 55.350856236049104, "min": 55.350856236049104}}, "EndTime": 1576474477.3341, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334082}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.17831856863839, "sum": 66.17831856863839, "min": 66.17831856863839}}, "EndTime": 1576474477.334165, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334147}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 60.24045671735491, "sum": 60.24045671735491, "min": 60.24045671735491}}, "EndTime": 1576474477.334225, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334208}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 52.172677176339285, "sum": 52.172677176339285, "min": 52.172677176339285}}, "EndTime": 1576474477.334295, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334278}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 88.55587332589286, "sum": 88.55587332589286, "min": 88.55587332589286}}, "EndTime": 1576474477.33436, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334342}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.076747349330354, "sum": 50.076747349330354, "min": 50.076747349330354}}, "EndTime": 1576474477.334419, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334402}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.56006731305804, "sum": 68.56006731305804, "min": 68.56006731305804}}, "EndTime": 1576474477.334488, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.33447}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 57.89294869559152, "sum": 57.89294869559152, "min": 57.89294869559152}}, "EndTime": 1576474477.33455, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334533}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.75944301060268, "sum": 63.75944301060268, "min": 63.75944301060268}}, "EndTime": 1576474477.334612, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334595}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 44.703848702566965, "sum": 44.703848702566965, "min": 44.703848702566965}}, "EndTime": 1576474477.334674, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334658}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.052908761160715, "sum": 54.052908761160715, "min": 54.052908761160715}}, "EndTime": 1576474477.334735, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334718}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.89984566824777, "sum": 63.89984566824777, "min": 63.89984566824777}}, "EndTime": 1576474477.334797, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.33478}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 48.54451206752232, "sum": 48.54451206752232, "min": 48.54451206752232}}, "EndTime": 1576474477.334856, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.33484}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 76.03030831473214, "sum": 76.03030831473214, "min": 76.03030831473214}}, "EndTime": 1576474477.334919, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334902}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 61.265267508370535, "sum": 61.265267508370535, "min": 61.265267508370535}}, "EndTime": 1576474477.334978, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.334961}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 29.16658673967634, "sum": 29.16658673967634, "min": 29.16658673967634}}, "EndTime": 1576474477.335039, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335022}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.969020298549104, "sum": 53.969020298549104, "min": 53.969020298549104}}, "EndTime": 1576474477.335099, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335083}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 33.93070329938616, "sum": 33.93070329938616, "min": 33.93070329938616}}, "EndTime": 1576474477.335159, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335143}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 34.00806100027902, "sum": 34.00806100027902, "min": 34.00806100027902}}, "EndTime": 1576474477.335223, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335204}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.79528372628349, "sum": 65.79528372628349, "min": 65.79528372628349}}, "EndTime": 1576474477.335284, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335266}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.234592982700896, "sum": 63.234592982700896, "min": 63.234592982700896}}, "EndTime": 1576474477.335347, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335328}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 82.81587437220982, "sum": 82.81587437220982, "min": 82.81587437220982}}, "EndTime": 1576474477.335409, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335391}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 76.41783796037946, "sum": 76.41783796037946, "min": 76.41783796037946}}, "EndTime": 1576474477.335469, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335453}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 75.35414341517857, "sum": 75.35414341517857, "min": 75.35414341517857}}, "EndTime": 1576474477.335529, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335512}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 78.679443359375, "sum": 78.679443359375, "min": 78.679443359375}}, "EndTime": 1576474477.33559, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335572}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.56772286551339, "sum": 70.56772286551339, "min": 70.56772286551339}}, "EndTime": 1576474477.335652, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335635}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 72.09714181082589, "sum": 72.09714181082589, "min": 72.09714181082589}}, "EndTime": 1576474477.335713, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576474477.335695}
#
# ...
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9406242370605469, "sum": 0.9406242370605469, "min": 0.9406242370605469}}, "EndTime": 1576474478.345289, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.345271}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0030780029296875, "sum": 1.0030780029296875, "min": 1.0030780029296875}}, "EndTime": 1576474478.345353, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.345336}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8804324340820312, "sum": 0.8804324340820312, "min": 0.8804324340820312}}, "EndTime": 1576474478.345417, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.3454}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0265027618408202, "sum": 1.0265027618408202, "min": 1.0265027618408202}}, "EndTime": 1576474478.345481, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.345464}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0402454376220702, "sum": 1.0402454376220702, "min": 1.0402454376220702}}, "EndTime": 1576474478.345545, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.345527}
#
# [12/16/2019 05:34:38 INFO 140618816755520] #quality_metric: host=algo-1, epoch=13, train mse_objective <loss>=0.553032112122
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 32.41803196498326, "sum": 32.41803196498326, "min": 32.41803196498326}}, "EndTime": 1576474478.395785, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.395695}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 31.08323233468192, "sum": 31.08323233468192, "min": 31.08323233468192}}, "EndTime": 1576474478.395881, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.39586}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 40.920889718191965, "sum": 40.920889718191965, "min": 40.920889718191965}}, "EndTime": 1576474478.395953, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.395932}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 31.704980032784597, "sum": 31.704980032784597, "min": 31.704980032784597}}, "EndTime": 1576474478.396026, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396006}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 35.8340824672154, "sum": 35.8340824672154, "min": 35.8340824672154}}, "EndTime": 1576474478.396093, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396076}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 23.878387451171875, "sum": 23.878387451171875, "min": 23.878387451171875}}, "EndTime": 1576474478.396154, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396138}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 27.107264927455358, "sum": 27.107264927455358, "min": 27.107264927455358}}, "EndTime": 1576474478.396208, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396194}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 32.333949497767854, "sum": 32.333949497767854, "min": 32.333949497767854}}, "EndTime": 1576474478.396263, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396249}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 35.66117422921317, "sum": 35.66117422921317, "min": 35.66117422921317}}, "EndTime": 1576474478.396316, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396302}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 41.941009521484375, "sum": 41.941009521484375, "min": 41.941009521484375}}, "EndTime": 1576474478.396367, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396354}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 33.12925066266741, "sum": 33.12925066266741, "min": 33.12925066266741}}, "EndTime": 1576474478.39642, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396407}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 37.236301967075896, "sum": 37.236301967075896, "min": 37.236301967075896}}, "EndTime": 1576474478.396473, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396459}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 29.632226126534597, "sum": 29.632226126534597, "min": 29.632226126534597}}, "EndTime": 1576474478.396526, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396512}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 29.993055071149552, "sum": 29.993055071149552, "min": 29.993055071149552}}, "EndTime": 1576474478.396578, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396564}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 36.626124790736604, "sum": 36.626124790736604, "min": 36.626124790736604}}, "EndTime": 1576474478.39663, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396616}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 27.877559116908483, "sum": 27.877559116908483, "min": 27.877559116908483}}, "EndTime": 1576474478.396681, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396667}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 35.36300005231585, "sum": 35.36300005231585, "min": 35.36300005231585}}, "EndTime": 1576474478.396734, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.39672}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 30.718917846679688, "sum": 30.718917846679688, "min": 30.718917846679688}}, "EndTime": 1576474478.396787, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396773}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.00068882533482, "sum": 43.00068882533482, "min": 43.00068882533482}}, "EndTime": 1576474478.396839, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396825}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 35.12768990652902, "sum": 35.12768990652902, "min": 35.12768990652902}}, "EndTime": 1576474478.396891, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396877}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 27.815508161272323, "sum": 27.815508161272323, "min": 27.815508161272323}}, "EndTime": 1576474478.396944, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.39693}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 20.559583391462052, "sum": 20.559583391462052, "min": 20.559583391462052}}, "EndTime": 1576474478.396996, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.396982}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 31.420968191964285, "sum": 31.420968191964285, "min": 31.420968191964285}}, "EndTime": 1576474478.397047, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397033}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 31.521209716796875, "sum": 31.521209716796875, "min": 31.521209716796875}}, "EndTime": 1576474478.397099, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397085}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.74635968889508, "sum": 68.74635968889508, "min": 68.74635968889508}}, "EndTime": 1576474478.397151, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397137}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.16180419921875, "sum": 66.16180419921875, "min": 66.16180419921875}}, "EndTime": 1576474478.397204, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397189}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 61.33805629185268, "sum": 61.33805629185268, "min": 61.33805629185268}}, "EndTime": 1576474478.397259, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397245}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.209315708705354, "sum": 63.209315708705354, "min": 63.209315708705354}}, "EndTime": 1576474478.397311, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397297}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.3345206124442, "sum": 66.3345206124442, "min": 66.3345206124442}}, "EndTime": 1576474478.397368, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.39735}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 61.30185808454241, "sum": 61.30185808454241, "min": 61.30185808454241}}, "EndTime": 1576474478.397424, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397409}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.24293300083706, "sum": 71.24293300083706, "min": 71.24293300083706}}, "EndTime": 1576474478.397477, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397463}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.10505022321429, "sum": 70.10505022321429, "min": 70.10505022321429}}, "EndTime": 1576474478.39753, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.397516}
#
# [12/16/2019 05:34:38 INFO 140618816755520] #quality_metric: host=algo-1, epoch=13, validation mse_objective <loss>=32.418031965
# [12/16/2019 05:34:38 INFO 140618816755520] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=20.5595833915
# [12/16/2019 05:34:38 INFO 140618816755520] Early stop condition met. Stopping training.
# [12/16/2019 05:34:38 INFO 140618816755520] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Total Batches Seen": {"count": 1, "max": 31, "sum": 31.0, "min": 31}, "Total Records Seen": {"count": 1, "max": 3605, "sum": 3605.0, "min": 3605}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1576474478.398644, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1576474478.315397}
#
# [12/16/2019 05:34:38 INFO 140618816755520] #throughput_metric: host=algo-1, train throughput=2722.44480092 records/second
# [12/16/2019 05:34:38 WARNING 140618816755520] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/16/2019 05:34:38 WARNING 140618816755520] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/16/2019 05:34:38 INFO 140618816755520] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=20.5595833915
# [12/16/2019 05:34:38 INFO 140618816755520] #validation_score (algo-1) : ('mse_objective', 14.839900425502233)
# [12/16/2019 05:34:38 INFO 140618816755520] #validation_score (algo-1) : ('mse', 14.839900425502233)
# [12/16/2019 05:34:38 INFO 140618816755520] #validation_score (algo-1) : ('absolute_loss', 2.8286544254847934)
# [12/16/2019 05:34:38 INFO 140618816755520] #quality_metric: host=algo-1, validation mse_objective <loss>=14.8399004255
# [12/16/2019 05:34:38 INFO 140618816755520] #quality_metric: host=algo-1, validation mse <loss>=14.8399004255
# [12/16/2019 05:34:38 INFO 140618816755520] #quality_metric: host=algo-1, validation absolute_loss <loss>=2.82865442548
# [12/16/2019 05:34:38 INFO 140618816755520] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [12/16/2019 05:34:38 INFO 140618816755520] Saved checkpoint to "/tmp/tmpESJagK/mx-mod-0000.params"
# [12/16/2019 05:34:38 INFO 140618816755520] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1548.9461421966553, "sum": 1548.9461421966553, "min": 1548.9461421966553}, "finalize.time": {"count": 1, "max": 70.21403312683105, "sum": 70.21403312683105, "min": 70.21403312683105}, "initialize.time": {"count": 1, "max": 149.86705780029297, "sum": 149.86705780029297, "min": 149.86705780029297}, "check_early_stopping.time": {"count": 15, "max": 1.5978813171386719, "sum": 9.799003601074219, "min": 0.20384788513183594}, "setuptime": {"count": 1, "max": 26.971101760864258, "sum": 26.971101760864258, "min": 26.971101760864258}, "update.time": {"count": 14, "max": 111.50789260864258, "sum": 1227.046012878418, "min": 76.81512832641602}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1576474478.478638, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576474477.014958}
# 2019-12-16 05:34:46 Uploading - Uploading generated training model
# 2019-12-16 05:34:46 Completed - Training job completed
# Training seconds: 53
# Billable seconds: 53

# %% [markdown]
# ## Step 6 (B): Deploy the trained model
#
# Similar to the XGBoost model, now that we've fit the model we need to deploy it. Also like the XGBoost model, we will use the lower level approach so that we have more control over the endpoint that gets created.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
# First, we create a unique model name
linear_model_name = "boston-update-linear-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the linear-learner container that we used for training
# can also be used for inference.
linear_primary_container = {
    "Image": linear_container,
    "ModelDataUrl": linear.model_data
}

# And lastly we construct the SageMaker model
linear_model_info = session.sagemaker_client.create_model(
                                ModelName = linear_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = linear_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have the model we can start putting together the endpoint by creating an endpoint configuration.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
linear_endpoint_config_name = "boston-linear-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
linear_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = linear_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": linear_model_name,
                                "VariantName": "Linear-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = linear_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# ---------------------------------------------------------------------------------------------------------------!

# %% [markdown]
# ## Step 7 (B): Use the model
#
# Just like with the XGBoost model, we will send some data to our endpoint to make sure that it is working properly. An important note is that the output format for the linear model is different from the XGBoost model.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f885c0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 16 Dec 2019 05:45:26 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '228ad938-8526-4e63-8b11-50bb34371559'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '228ad938-8526-4e63-8b11-50bb34371559',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '{"predictions": [{"score": 33.50567626953125}]}'

# %%
Y_test.values[0]
# Out:
# array([43.1])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the Linear model's endpoint works, we can shut it down.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '678d5480-8772-40fb-8b07-e5b40da2b2d4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '678d5480-8772-40fb-8b07-e5b40da2b2d4',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Mon, 16 Dec 2019 05:45:33 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 6 (C): Deploy a combined model
#
# So far we've constructed two separate models which we could deploy and use. Before we talk about how we can change a deployed endpoint from one configuration to another, let's consider a slightly different situation. Suppose that before we switch from using only the XGBoost model to only the Linear model, we first want to do something like an A-B test, where we send some of the incoming data to the XGBoost model and some of the data to the Linear model.
#
# Fortunately, SageMaker provides this functionality. And to actually get SageMaker to do this for us is not too different from deploying a model in the way that we've already done. The only difference is that we need to list more than one model in the production variants parameter of the endpoint configuration.
#
# A reasonable question to ask is, how much data is sent to each of the models that I list in the production variants parameter? The answer is that it depends on the weight set for each model.
#
# Suppose that we have $k$ models listed in the production variants and that each model $i$ is assigned the weight $w_i$. Then each model $i$ will receive $w_i / W$ of the traffic where $W = \sum_{i} w_i$.
#
# In our case, since we have two models, the linear model and the XGBoost model, and each model has weight 1, we see that each model will get 1 / (1 + 1) = 1/2 of the data sent to the endpoint.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
combined_endpoint_config_name = "boston-combined-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
combined_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = combined_endpoint_config_name,
                            ProductionVariants = [
                                { # First we include the linear model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": linear_model_name,
                                    "VariantName": "Linear-Model"
                                }, { # And next we include the xgb model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": xgb_model_name,
                                    "VariantName": "XGB-Model"
                                }])

# %% [markdown]
# Now that we've created the endpoint configuration, we can ask SageMaker to construct the endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = combined_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# ---------------------------------------------------------------------------------------------------------------!

# %% [markdown]
# ## Step 7 (C): Use the model
#
# Now that we've constructed an endpoint which sends data to both the XGBoost model and the linear model we can send some data to the endpoint and see what sort of results we get back.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f3efd0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 16 Dec 2019 06:01:31 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '15eccc4f-ff51-4472-a707-dc3c3bcf8efc'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '15eccc4f-ff51-4472-a707-dc3c3bcf8efc',
#                       'RetryAttempts': 0}}

# %% [markdown]
# Since looking at a single response doesn't give us a clear look at what is happening, we can instead take a look at a few different responses to our endpoint

# %%
for rec in range(10):
    response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[rec])))
    pprint(response)
    result = response['Body'].read().decode("utf-8")
    print(result)
    print(Y_test.values[rec])
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f3d898>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'cea1dde5-0e7c-4c15-98f9-b8022c29be91'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'cea1dde5-0e7c-4c15-98f9-b8022c29be91',
#                       'RetryAttempts': 0}}
# 40.9679641724
# [43.1]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f3d6d8>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '53448fe4-0fde-4ee8-b833-441b6e3fea18'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '53448fe4-0fde-4ee8-b833-441b6e3fea18',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 18.408302307128906}]}
# [19.6]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f3d4a8>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '5c2efe28-3ed1-4005-a115-cb282837fced'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '5c2efe28-3ed1-4005-a115-cb282837fced',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 18.77135467529297}]}
# [20.6]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f4c978>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '0a3523ca-c542-47b8-b69f-d5a60bb53423'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0a3523ca-c542-47b8-b69f-d5a60bb53423',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 17.354595184326172}]}
# [15.2]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f4cbe0>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '0c07a147-d454-4e03-957a-6f13b860330a'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0c07a147-d454-4e03-957a-6f13b860330a',
#                       'RetryAttempts': 0}}
# 20.6159896851
# [21.7]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f4ce48>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '83f0f251-6198-46ee-8458-707d87812cf9'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '83f0f251-6198-46ee-8458-707d87812cf9',
#                       'RetryAttempts': 0}}
# 15.6462497711
# [14.2]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f4cac8>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '91767ceb-d63c-4c9e-bc1d-c9580f42a78e'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '91767ceb-d63c-4c9e-bc1d-c9580f42a78e',
#                       'RetryAttempts': 0}}
# 23.0768699646
# [22.]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62ff41d0>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '11',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '1f153679-7198-40d7-9003-769b9fcccdd1'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '1f153679-7198-40d7-9003-769b9fcccdd1',
#                       'RetryAttempts': 0}}
# 22.70195961
# [20.4]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f3d160>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '4b5173b8-b5c7-428b-8b68-3a1811f181cf'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '4b5173b8-b5c7-428b-8b68-3a1811f181cf',
#                       'RetryAttempts': 0}}
# 20.5657730103
# [21.4]
# {'Body': <botocore.response.StreamingBody object at 0x7fca62f3d9e8>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Mon, 16 Dec 2019 06:01:33 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '4ed7d054-6023-4cb7-a85b-93e6824c6b19'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '4ed7d054-6023-4cb7-a85b-93e6824c6b19',
#                       'RetryAttempts': 0}}
# 17.0577964783
# [15.6]

# %% [markdown]
# If at some point we aren't sure about the properties of a deployed endpoint, we can use the `describe_endpoint` function to get SageMaker to return a description of the deployed endpoint.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2019, 12, 16, 5, 49, 50, 79000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:802725115046:endpoint/boston-update-endpoint-2019-12-16-05-49-49',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2019-12-16-05-49-47',
#  'EndpointName': 'boston-update-endpoint-2019-12-16-05-49-49',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2019, 12, 16, 5, 59, 11, 654000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2019, 12, 16, 5, 49, 52, 28000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:0968670c29a5901e4cf38d3e690c3550e6c38539e0f004ccc79bb1e56d8b452b',
#                                              'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2019, 12, 16, 5, 49, 52, 99000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost@sha256:5fe3063b6797a14fec0da6c3c6d6b8cb484773c595864e91b85fa1e6168d3a38',
#                                              'SpecifiedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1162',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Mon, 16 Dec 2019 06:01:58 GMT',
#                                       'x-amzn-requestid': 'da7f9dcb-6123-45fc-a0f4-2fdca7e9ee72'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'da7f9dcb-6123-45fc-a0f4-2fdca7e9ee72',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## Updating an Endpoint
#
# Now suppose that we've done our A-B test and the new linear model is working well enough. What we'd like to do now is to switch our endpoint from sending data to both the XGBoost model and the linear model to sending data only to the linear model.
#
# Of course, we don't really want to shut down the endpoint to do this as doing so would interrupt service to whoever depends on our endpoint. Instead, we can ask SageMaker to **update** an endpoint to a new endpoint configuration.
#
# What is actually happening is that SageMaker will set up a new endpoint with the new characteristics. Once this new endpoint is running, SageMaker will switch the old endpoint so that it now points at the newly deployed model, making sure that this happens seamlessly in the background.

# %%
session.sagemaker_client.update_endpoint(EndpointName=endpoint_name, EndpointConfigName=linear_endpoint_config_name)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-48-ae9c788297e8> in <module>()
# ----> 1 session.sagemaker_client.update_endpoint(EndpointName=endpoint_name, EndpointConfigName=linear_endpoint_config_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     659             error_code = parsed_response.get("Error", {}).get("Code")
#     660             error_class = self.exceptions.from_code(error_code)
# --> 661             raise error_class(parsed_response, operation_name)
#     662         else:
#     663             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the UpdateEndpoint operation: Could not find endpoint configuration "arn:aws:sagemaker:us-east-1:802725115046:endpoint-config/boston-linear-endpoint-config-2019-12-16-05-35-28".

# %% [markdown]
# To get a glimpse at what is going on, we can ask SageMaker to describe our in-use endpoint now, before the update process has completed. When we do so, we can see that the in-use endpoint still has the same characteristics it had before.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2019, 12, 16, 5, 49, 50, 79000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:802725115046:endpoint/boston-update-endpoint-2019-12-16-05-49-49',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2019-12-16-05-49-47',
#  'EndpointName': 'boston-update-endpoint-2019-12-16-05-49-49',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2019, 12, 16, 5, 59, 11, 654000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2019, 12, 16, 5, 49, 52, 28000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:0968670c29a5901e4cf38d3e690c3550e6c38539e0f004ccc79bb1e56d8b452b',
#                                              'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2019, 12, 16, 5, 49, 52, 99000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost@sha256:5fe3063b6797a14fec0da6c3c6d6b8cb484773c595864e91b85fa1e6168d3a38',
#                                              'SpecifiedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1162',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Mon, 16 Dec 2019 06:03:20 GMT',
#                                       'x-amzn-requestid': '83f194d5-b555-4f54-bc9f-ac5c93464cf5'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '83f194d5-b555-4f54-bc9f-ac5c93464cf5',
#                       'RetryAttempts': 0}}

# %% [markdown]
# If we now wait for the update process to complete, and then ask SageMaker to describe the endpoint, it will return the characteristics of the new endpoint configuration.

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# !

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2019, 12, 16, 5, 49, 50, 79000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:802725115046:endpoint/boston-update-endpoint-2019-12-16-05-49-49',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2019-12-16-05-49-47',
#  'EndpointName': 'boston-update-endpoint-2019-12-16-05-49-49',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2019, 12, 16, 5, 59, 11, 654000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2019, 12, 16, 5, 49, 52, 28000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:0968670c29a5901e4cf38d3e690c3550e6c38539e0f004ccc79bb1e56d8b452b',
#                                              'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2019, 12, 16, 5, 49, 52, 99000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost@sha256:5fe3063b6797a14fec0da6c3c6d6b8cb484773c595864e91b85fa1e6168d3a38',
#                                              'SpecifiedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1162',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Mon, 16 Dec 2019 06:03:24 GMT',
#                                       'x-amzn-requestid': 'ef7b0b69-c1f5-42f9-b532-7d88b5fe90ff'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'ef7b0b69-c1f5-42f9-b532-7d88b5fe90ff',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we've finished, we need to make sure to shut down the endpoint.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'f9ff1b0d-e281-43fc-b259-b9ce79eca65f',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f9ff1b0d-e281-43fc-b259-b9ce79eca65f',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Mon, 16 Dec 2019 06:03:26 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir
