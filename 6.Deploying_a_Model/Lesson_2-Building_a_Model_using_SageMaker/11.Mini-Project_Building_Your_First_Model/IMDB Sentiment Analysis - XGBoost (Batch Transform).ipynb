# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# As our first example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there may be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2019-12-09 16:51:06--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  22.8MB/s    in 4.9s
#
# 2019-12-09 16:51:11 (16.4 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# 'Although recognized as the best film treatment of the difficulties of having a house in the country built (or bought) to your specifications, it is not the first, nor the last. In 1940 Jack Benny and Ann Sheridan were the leads in the film version of the comedy GEORGE WASHINGTON SLEPT HERE by George S. Kaufman and Moss Hart. And about fifteen years ago Shelly Long and Tom Hanks had the lead in THE MONEY PIT. The former was about moving into an 18th Century country house that...err, needs work. The latter was about building your dream house - in the late 1980s. Although the two films have their moments, both are not as good as BLANDINGS, which was based on an autobiographical novel of the same name.<br /><br />Jim Blandings and his wife Muriel (Cary Grant and Myrna Loy) are noticing the tight corners of their apartment, which they share with their two daughters Joan and Betsy (Sharyn Moffett and Connie Marshall). Although Blandings has a good income as an advertising executive (in 1948 he is making $15,000.00 a year, which was like making $90,000.00 today), and lives in a luxury apartment - which in the New York City of that day he rents! - he feels they should seek something better. He and Muriel take a drive into the country (Connecticut) and soon find an old ruin that both imagine can be fixed up as that dream house they want.<br /><br />And they both fall into the financial worm hole that buying land and construction can lead to. For one thing, they are so gung ho about the idea of building a home like this they fail to heed warning after warning by their wise, if cynical friend and lawyer Bill Cole (Melvin Douglas, in a nicely sardonic role). For example, Jim buys land from a Connecticut dealer (Ian Wolfe, sucking his chops quietly), with a check before double checking the correct cost for the land in that part of Connecticut. Bill points out he\'s paid about five or six thousand dollars more for the land than it is worth. There are problems about water supply that both Blandings just never think about, such as hard and soft water - which leads to the Zis - Zis Water softening machine. They find that the designs they have in mind, and have worked out with their architect (Reginald Denny), can\'t be dropped cheaply at a spur of the moment decision by Muriel to build a little rookery that nobody planned for. <br /><br />The escalating costs of the project are one matter that bedevils Jim. He has been appointed to handle the "Wham" account ("Spam" had become a popular result of World War II, in that the public started using it as a meat substitute, in the light of it\'s success with the armed forces). Jim can\'t get a grip on this (he\'s not alone - one or two other executives fumbled it before him). He comes up with the following bit of "poetry"(?):<br /><br />"This little piggy went to market,<br /><br />He was pink and as pretty as ham.<br /><br />He smiled in his tracks,<br /><br />As they gave him the ax -<br /><br />He knew he would end up as "Wham"!"<br /><br />His Secretary looks at him as though he needs a straight jacket when he reads that one!<br /><br />Jim also is increasingly suspicious of the attentions of Bill to Muriel, although (in this case) Bill is blameless. But he\'s always around (Jim keeps forgetting that Bill is the clearheaded one, and that he\'s keeping Jim and Muriel from making so many mistakes). All three have mishaps, the best being when they get locked in a room in the half constructed house, just as the men have left for the day. They can\'t open the door, and Jim (in a panic) tries breaking the door down by a make-shift battering ram. He breaks a window, and the door opens by itself.<br /><br />The film works quite satisfactorily, with all of the actors apparently enjoying themselves. It is one film which (despite changing price levels and salary levels) really does not age at all. After all, most Americans dream of owning their own home and always have.<br /><br />A number of years ago a pa ...

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### (TODO) Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

# TODO: Split the train_X and train_y arrays into the DataFrames val_X, train_X and val_y, train_y. Make sure that
#       val_X and val_y contain 10 000 entires while train_X and train_y contain the remaining 15 000 entries.
val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# TODO: Save the training and validation data to train.csv and validation.csv in the data_dir directory.
#       Make sure that the files you create are in the correct format.
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### (TODO) Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

# TODO: Upload the test.csv, train.csv and validation.csv files which are contained in data_dir to S3 using sess.upload_data().
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container,
                                    role,
                                    train_instance_count=1,
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)


# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2019-12-09 17:07:42 Starting - Starting the training job...
# 2019-12-09 17:07:43 Starting - Launching requested ML instances......
# 2019-12-09 17:08:48 Starting - Preparing the instances for training......
# 2019-12-09 17:09:44 Downloading - Downloading input data...
# 2019-12-09 17:10:36 Training - Training image download completed. Training in progress..Arguments: train
# [2019-12-09:17:10:37:INFO] Running standalone xgboost training.
# [2019-12-09:17:10:37:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8515.11mb
# [2019-12-09:17:10:37:INFO] Determined delimiter of CSV input is ','
# [17:10:37] S3DistributionType set as FullyReplicated
# [17:10:39] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2019-12-09:17:10:39:INFO] Determined delimiter of CSV input is ','
# [17:10:39] S3DistributionType set as FullyReplicated
# [17:10:40] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [17:10:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=5
# [0]#011train-error:0.2812#011validation-error:0.2887
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
#
# Will train until validation-error hasn't improved in 10 rounds.
# [17:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=5
# [1]#011train-error:0.278667#011validation-error:0.2842
# [17:10:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [2]#011train-error:0.271267#011validation-error:0.2782
# [17:10:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [3]#011train-error:0.269733#011validation-error:0.28
# [17:10:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [4]#011train-error:0.266933#011validation-error:0.2749
# [17:10:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=5
# [5]#011train-error:0.254933#011validation-error:0.2644
# [17:10:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [6]#011train-error:0.249#011validation-error:0.2576
# [17:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [7]#011train-error:0.241333#011validation-error:0.2499
# [17:10:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [8]#011train-error:0.233733#011validation-error:0.244
# [17:10:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [9]#011train-error:0.2288#011validation-error:0.2384
# [17:10:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [10]#011train-error:0.222933#011validation-error:0.2352
# [17:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 8 pruned nodes, max_depth=5
# [11]#011train-error:0.2166#011validation-error:0.2298
# [17:10:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [12]#011train-error:0.213467#011validation-error:0.2264
# [17:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=5
# [13]#011train-error:0.208267#011validation-error:0.2209
# [17:11:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [14]#011train-error:0.2048#011validation-error:0.2192
# [17:11:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [15]#011train-error:0.202533#011validation-error:0.2181
# [17:11:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [16]#011train-error:0.1988#011validation-error:0.2136
# [17:11:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [17]#011train-error:0.1964#011validation-error:0.2114
# [17:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [18]#011train-error:0.193067#011validation-error:0.2098
# [17:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [19]#011train-error:0.1908#011validation-error:0.2079
# [17:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=5
# [20]#011train-error:0.187067#011validation-error:0.204
# [17:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [21]#011train-error:0.185533#011validation-error:0.2012
# [17:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [22]#011train-error:0.182533#011validation-error:0.1984
# [17:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [23]#011train-error:0.180067#011validation-error:0.1967
# [17:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [24]#011train-error:0.1774#011validation-error:0.1949
# [17:11:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [25]#011train-error:0.175067#011validation-error:0.1949
# [17:11:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [26]#011train-error:0.172533#011validation-error:0.1929
# [17:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=5
# [27]#011train-error:0.170733#011validation-error:0.192
# [17:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=5
# [28]#011train-error:0.169133#011validation-error:0.1909
# [17:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=5
# [29]#011train-error:0.167867#011validation-error:0.1897
# [17:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [30]#011train-error:0.166133#011validation-error:0.1887
# [17:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [31]#011train-error:0.164333#011validation-error:0.1873
# [17:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [32]#011train-error:0.1622#011validation-error:0.1849
# [17:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [33]#011train-error:0.160533#011validation-error:0.1841
# [17:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [34]#011train-error:0.159067#011validation-error:0.1834
# [17:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [35]#011train-error:0.159333#011validation-error:0.1839
# [17:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [36]#011train-error:0.157733#011validation-error:0.1843
# [17:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [37]#011train-error:0.156333#011validation-error:0.1825
# [17:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [38]#011train-error:0.155133#011validation-error:0.1808
# [17:11:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=5
# [39]#011train-error:0.152733#011validation-error:0.1806
# [17:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [40]#011train-error:0.153#011validation-error:0.1792
# [17:11:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [41]#011train-error:0.150933#011validation-error:0.1795
# [17:11:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [42]#011train-error:0.150667#011validation-error:0.1792
# [17:11:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [43]#011train-error:0.149267#011validation-error:0.1781
# [17:11:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [44]#011train-error:0.1484#011validation-error:0.1769
# [17:11:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [45]#011train-error:0.1468#011validation-error:0.1762
# [17:11:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [46]#011train-error:0.1448#011validation-error:0.1758
# [17:11:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [47]#011train-error:0.1436#011validation-error:0.1746
# [17:11:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [48]#011train-error:0.142267#011validation-error:0.1728
# [17:11:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 18 pruned nodes, max_depth=5
# [49]#011train-error:0.141133#011validation-error:0.1718
# [17:11:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=5
# [50]#011train-error:0.140533#011validation-error:0.1712
# [17:11:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [51]#011train-error:0.139467#011validation-error:0.1703
# [17:11:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [52]#011train-error:0.138467#011validation-error:0.1706
# [17:11:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [53]#011train-error:0.137933#011validation-error:0.1714
# [17:11:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [54]#011train-error:0.136267#011validation-error:0.1709
# [17:11:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [55]#011train-error:0.135067#011validation-error:0.1696
# [17:11:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [56]#011train-error:0.133267#011validation-error:0.1686
# [17:11:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [57]#011train-error:0.132933#011validation-error:0.1679
# [17:11:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [58]#011train-error:0.131933#011validation-error:0.168
# [17:11:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [59]#011train-error:0.131267#011validation-error:0.1677
# [17:11:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [60]#011train-error:0.131333#011validation-error:0.1672
# [17:12:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [61]#011train-error:0.130133#011validation-error:0.1665
# [17:12:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [62]#011train-error:0.129467#011validation-error:0.1653
# [17:12:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [63]#011train-error:0.128733#011validation-error:0.1642
# [17:12:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=5
# [64]#011train-error:0.128267#011validation-error:0.1634
# [17:12:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [65]#011train-error:0.127733#011validation-error:0.1631
# [17:12:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [66]#011train-error:0.127667#011validation-error:0.1629
# [17:12:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [67]#011train-error:0.126333#011validation-error:0.1632
# [17:12:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [68]#011train-error:0.1258#011validation-error:0.162
# [17:12:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [69]#011train-error:0.124533#011validation-error:0.1622
# [17:12:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [70]#011train-error:0.124333#011validation-error:0.1602
# [17:12:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [71]#011train-error:0.123333#011validation-error:0.1606
# [17:12:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [72]#011train-error:0.123933#011validation-error:0.1593
# [17:12:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [73]#011train-error:0.122533#011validation-error:0.158
# [17:12:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [74]#011train-error:0.121467#011validation-error:0.1574
# [17:12:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [75]#011train-error:0.122267#011validation-error:0.1584
# [17:12:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [76]#011train-error:0.1218#011validation-error:0.1599
# [17:12:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [77]#011train-error:0.121933#011validation-error:0.1584
# [17:12:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [78]#011train-error:0.1206#011validation-error:0.1587
# [17:12:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [79]#011train-error:0.119667#011validation-error:0.1586
# [17:12:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [80]#011train-error:0.1188#011validation-error:0.1584
# [17:12:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [81]#011train-error:0.117867#011validation-error:0.1576
# [17:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [82]#011train-error:0.118333#011validation-error:0.157
# [17:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [83]#011train-error:0.117533#011validation-error:0.1575
# [17:12:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [84]#011train-error:0.116067#011validation-error:0.1559
# [17:12:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [85]#011train-error:0.116467#011validation-error:0.1552
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [86]#011train-error:0.115533#011validation-error:0.1541
# [17:12:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [87]#011train-error:0.114667#011validation-error:0.1543
# [17:12:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [88]#011train-error:0.113667#011validation-error:0.1542
# [17:12:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [89]#011train-error:0.112333#011validation-error:0.1537
# [17:12:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [90]#011train-error:0.112467#011validation-error:0.1536
# [17:12:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [91]#011train-error:0.111533#011validation-error:0.154
# [17:12:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [92]#011train-error:0.111133#011validation-error:0.1534
# [17:12:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [93]#011train-error:0.110467#011validation-error:0.1523
# [17:12:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [94]#011train-error:0.110067#011validation-error:0.1513
# [17:12:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [95]#011train-error:0.109333#011validation-error:0.1523
# [17:12:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [96]#011train-error:0.1088#011validation-error:0.1522
# [17:12:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [97]#011train-error:0.108533#011validation-error:0.1518
# [17:12:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [98]#011train-error:0.108867#011validation-error:0.152
# [17:12:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [99]#011train-error:0.108467#011validation-error:0.1511
# [17:12:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [100]#011train-error:0.108467#011validation-error:0.1511
# [17:12:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [101]#011train-error:0.1082#011validation-error:0.1502
# [17:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [102]#011train-error:0.1078#011validation-error:0.1499
# [17:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [103]#011train-error:0.1066#011validation-error:0.1503
# [17:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [104]#011train-error:0.106133#011validation-error:0.1497
# [17:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [105]#011train-error:0.105533#011validation-error:0.1495
# [17:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [106]#011train-error:0.105467#011validation-error:0.1475
# [17:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [107]#011train-error:0.1062#011validation-error:0.148
# [17:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [108]#011train-error:0.105667#011validation-error:0.1474
# [17:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [109]#011train-error:0.1054#011validation-error:0.1463
# [17:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [110]#011train-error:0.105#011validation-error:0.1463
# [17:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [111]#011train-error:0.1026#011validation-error:0.1461
# [17:13:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [112]#011train-error:0.1024#011validation-error:0.1468
# [17:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [113]#011train-error:0.101267#011validation-error:0.1469
# [17:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=5
# [114]#011train-error:0.101133#011validation-error:0.1464
# [17:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [115]#011train-error:0.101267#011validation-error:0.1462
# [17:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [116]#011train-error:0.101#011validation-error:0.1457
# [17:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [117]#011train-error:0.1#011validation-error:0.1455
# [17:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [118]#011train-error:0.100333#011validation-error:0.1459
# [17:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [119]#011train-error:0.099133#011validation-error:0.145
# [17:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [120]#011train-error:0.098267#011validation-error:0.1439
# [17:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [121]#011train-error:0.098467#011validation-error:0.1443
# [17:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [122]#011train-error:0.097667#011validation-error:0.1433
# [17:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [123]#011train-error:0.0984#011validation-error:0.1441
# [17:13:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [124]#011train-error:0.097667#011validation-error:0.1445
# [17:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [125]#011train-error:0.097933#011validation-error:0.1435
# [17:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [126]#011train-error:0.097533#011validation-error:0.1436
# [17:13:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [127]#011train-error:0.097267#011validation-error:0.1431
# [17:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [128]#011train-error:0.097#011validation-error:0.1435
# [17:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [129]#011train-error:0.096667#011validation-error:0.1425
# [17:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [130]#011train-error:0.0958#011validation-error:0.1423
# [17:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [131]#011train-error:0.095333#011validation-error:0.1431
# [17:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [132]#011train-error:0.094667#011validation-error:0.1419
# [17:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [133]#011train-error:0.094667#011validation-error:0.1423
# [17:13:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [134]#011train-error:0.094467#011validation-error:0.1426
# [17:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [135]#011train-error:0.094133#011validation-error:0.1419
# [17:13:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=5
# [136]#011train-error:0.093867#011validation-error:0.142
# [17:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [137]#011train-error:0.092867#011validation-error:0.1418
# [17:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [138]#011train-error:0.093133#011validation-error:0.1419
# [17:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [139]#011train-error:0.093333#011validation-error:0.1422
# [17:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [140]#011train-error:0.093467#011validation-error:0.142
# [17:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [141]#011train-error:0.093333#011validation-error:0.141
# [17:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [142]#011train-error:0.092933#011validation-error:0.1407
# [17:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [143]#011train-error:0.093333#011validation-error:0.1405
# [17:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [144]#011train-error:0.091333#011validation-error:0.1404
# [17:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [145]#011train-error:0.092533#011validation-error:0.1405
# [17:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [146]#011train-error:0.092133#011validation-error:0.1408
# [17:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [147]#011train-error:0.090933#011validation-error:0.1404
# [17:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [148]#011train-error:0.091133#011validation-error:0.1403
# [17:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [149]#011train-error:0.0908#011validation-error:0.1401
# [17:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [150]#011train-error:0.090267#011validation-error:0.14
# [17:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [151]#011train-error:0.089933#011validation-error:0.14
# [17:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [152]#011train-error:0.089733#011validation-error:0.139
# [17:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [153]#011train-error:0.088733#011validation-error:0.1394
# [17:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [154]#011train-error:0.0882#011validation-error:0.1392
# [17:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [155]#011train-error:0.088667#011validation-error:0.1387
# [17:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [156]#011train-error:0.088733#011validation-error:0.1394
# [17:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [157]#011train-error:0.088267#011validation-error:0.1388
# [17:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [158]#011train-error:0.0882#011validation-error:0.139
# [17:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [159]#011train-error:0.0884#011validation-error:0.1374
# [17:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [160]#011train-error:0.0876#011validation-error:0.1376
# [17:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [161]#011train-error:0.087733#011validation-error:0.1372
# [17:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [162]#011train-error:0.086933#011validation-error:0.1375
# [17:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [163]#011train-error:0.086533#011validation-error:0.1373
# [17:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [164]#011train-error:0.085867#011validation-error:0.1374
# [17:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [165]#011train-error:0.0866#011validation-error:0.1385
# [17:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [166]#011train-error:0.086133#011validation-error:0.1384
# [17:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [167]#011train-error:0.085933#011validation-error:0.1386
# [17:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 24 pruned nodes, max_depth=5
# [168]#011train-error:0.085733#011validation-error:0.138
# [17:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [169]#011train-error:0.0864#011validation-error:0.138
# [17:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [170]#011train-error:0.086#011validation-error:0.1382
# [17:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 22 pruned nodes, max_depth=5
# [171]#011train-error:0.0858#011validation-error:0.1381
# Stopping. Best iteration:
# [161]#011train-error:0.087733#011validation-error:0.1372
#
#
# 2019-12-09 17:14:31 Uploading - Uploading generated training model
# 2019-12-09 17:14:31 Completed - Training job completed
# Training seconds: 287
# Billable seconds: 287

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
# TODO: Create a transformer object from the trained model. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.
xgb_transformer = xgb.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# .....................Arguments: serve
# [2019-12-09 17:29:45 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2019-12-09 17:29:45 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2019-12-09 17:29:45 +0000] [1] [INFO] Using worker: gevent
# [2019-12-09 17:29:45 +0000] [37] [INFO] Booting worker with pid: 37
# [2019-12-09 17:29:45 +0000] [38] [INFO] Booting worker with pid: 38
# [2019-12-09 17:29:45 +0000] [39] [INFO] Booting worker with pid: 39
# [2019-12-09:17:29:45:INFO] Model loaded successfully for worker : 37
# [2019-12-09 17:29:45 +0000] [40] [INFO] Booting worker with pid: 40
# [2019-12-09:17:29:45:INFO] Model loaded successfully for worker : 38
# [2019-12-09:17:29:45:INFO] Model loaded successfully for worker : 39
# [2019-12-09:17:29:45:INFO] Model loaded successfully for worker : 40
# [2019-12-09:17:30:18:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:18:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:18:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:18:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:18:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:18:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:18:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:18:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:18:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:18:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:19:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:18:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:18:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:19:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:19:INFO] Determined delimiter of CSV input is ','
# 2019-12-09T17:30:15.502:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:21:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:23:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:23:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:25:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:25:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:25:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:25:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:26:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:25:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:25:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:25:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:25:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:26:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:26:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:26:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:28:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:28:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:28:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:28:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:28:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:28:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:28:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:28:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:28:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:28:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:28:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:28:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:30:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:30:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:30:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:30:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:30:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:30:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:31:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:30:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:30:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:30:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:30:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:30:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:30:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:31:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:32:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:32:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:33:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:33:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:32:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:32:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:33:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:33:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:33:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:33:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:35:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:35:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:37:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:37:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:37:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:37:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:37:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:37:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:37:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:37:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:37:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:37:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:37:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:37:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:40:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:40:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:40:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:40:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:40:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:40:INFO] Determined delimiter of CSV input is ','
# [2019-12-09:17:30:40:INFO] Sniff delimiter as ','
# [2019-12-09:17:30:40:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-802725115046/xgboost-2019-12-09-17-26-25-385/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.8642

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
